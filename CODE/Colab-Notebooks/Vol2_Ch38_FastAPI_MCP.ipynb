# %% [markdown]
# # Chapter 38: FastAPI Server with MCP Integration
#
# **Production REST API Gateway with MCP Tool Bridges**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/eduardd76/AI_for_networking_and_security_engineers/blob/main/CODE/Colab-Notebooks/Vol2_Ch38_FastAPI_MCP.ipynb)

# %%
# !pip install -q fastapi uvicorn langchain langchain-anthropic
import os
from getpass import getpass
if 'ANTHROPIC_API_KEY' not in os.environ:
    os.environ['ANTHROPIC_API_KEY'] = getpass('Enter API key: ')
print('✓ Ready!')

# %% [markdown]
# ## Run Examples
#
# See the Python files in the repository for complete working code!

# %%
# Copy code from the corresponding chapter Python file and run here
print("Examples ready to run!")
