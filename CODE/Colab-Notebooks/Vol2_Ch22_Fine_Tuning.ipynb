# %% [markdown]
# # Volume 2, Chapter 22: Fine-Tuning Basics\n\n**Prepare training data and fine-tune models for network tasks**\n\n[![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/eduardd76/AI_for_networking_and_security_engineers/blob/main/CODE/Colab-Notebooks/Vol2_Ch22_Fine_Tuning)

# %%
# Setup\n!pip install -q anthropic openai\n\nimport os\nfrom getpass import getpass\nif 'ANTHROPIC_API_KEY or OPENAI_API_KEY' not in os.environ:\n    os.environ['ANTHROPIC_API_KEY or OPENAI_API_KEY'] = getpass('Enter ANTHROPIC_API_KEY or OPENAI_API_KEY: ')\nprint("✓ Ready!")

# %% [markdown]
# ## Examples\n\nThis notebook demonstrates:\n- Create syslog classification training data\n- Create config generation training data\n- Validate training data quality\n- Fine-tuning workflow guide\n

# %%
# Run the examples from the Python file\n# Copy code from the corresponding chapter and paste here\n\nprint("See the Python files in the repository for complete working code!")

# %% [markdown]
# ## Try Your Own\n\nExperiment with your own network configurations or questions below!

# %%
your_input = input("Enter your network config or question: ")\n# Process your input here\nprint(f"Processing: {your_input}")
