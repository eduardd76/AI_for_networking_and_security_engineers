# %% [markdown]
# # Volume 2, Chapter 18: Hybrid Retrieval\n\n**Advanced RAG with BM25 + Vector Search for better accuracy**\n\n[![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/eduardd76/AI_for_networking_and_security_engineers/blob/master/CODE/Colab-Notebooks/Vol2_Ch18_Hybrid_RAG)

# %%
# Setup\n!pip install -q langchain langchain-anthropic langchain-openai chromadb\n\nimport os\nfrom getpass import getpass\nif 'ANTHROPIC_API_KEY and OPENAI_API_KEY' not in os.environ:\n    os.environ['ANTHROPIC_API_KEY and OPENAI_API_KEY'] = getpass('Enter ANTHROPIC_API_KEY and OPENAI_API_KEY: ')\nprint("✓ Ready!")

# %% [markdown]
# ## Examples\n\nThis notebook demonstrates:\n- Build hybrid retriever (BM25 + Vector)\n- Compare retrieval methods\n- Q&A with hybrid RAG\n- Production RAG pipeline\n

# %%
# Run the examples from the Python file\n# Copy code from the corresponding chapter and paste here\n\nprint("See the Python files in the repository for complete working code!")

# %% [markdown]
# ## Try Your Own\n\nExperiment with your own network configurations or questions below!

# %%
your_input = input("Enter your network config or question: ")\n# Process your input here\nprint(f"Processing: {your_input}")
