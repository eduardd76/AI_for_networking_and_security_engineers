# %% [markdown]
# # Welcome to Volume 4: AI-Powered Security Operations
# This volume covers AI-driven SOC operations, threat detection, incident response, and advanced security automation for modern enterprise environments.

# %%
print("Welcome to Volume 4: AI Security Operations")
print("=" * 50)
chapters = [
    "Ch57: Intro to AI SecOps",
    "Ch58: Network Traffic Analysis",
    "Ch59: ML-Based IDS",
    "Ch60: Malware Analysis",
    "Ch61: Event Correlation",
    "Ch62: Threat Hunting",
    "Ch63: SOC Operations",
    "Ch64: UEBA",
    "Ch65: AI Threat Detection",
    "Ch66: Incident Response",
    "Ch67: Deception Technology",
    "Ch68: Container Security",
    "Ch69: Cloud Security",
    "Ch70: Threat Detection",
    "Ch71: Zero Trust",
    "Ch72: SIEM Integration",
    "Ch73: Digital Forensics",
    "Ch74: Cyber Threat Intelligence",
    "Ch75: Anomaly Detection",
    "Ch76: Application Security",
]
for i, ch in enumerate(chapters, 1): print(f"  {i:2d}. {ch}")
print(f"Total: {len(chapters)} chapters")

# %% [markdown]
# ## Prerequisites
# - Python 3.8+
# - Volumes 1-3 recommended
# - Basic networking and security knowledge
#
# ## Learning Outcomes
# - Deploy AI-powered threat detection systems
# - Automate SOC workflows and incident response
# - Implement behavioral analytics and UEBA
# - Master cloud and container security posture management

# %%
print("Environment check:")
import sys, platform
print("Python:", sys.version[:20])
print("Platform:", platform.system())
print("Ready to begin AI Security Operations!")
